# %%
import sqlite3
from pandas import DataFrame

# %%
conn = sqlite3.connect('XXX/Housing/Data_house_final.db')  # You can create a new database by changing the name within the quotes
c = conn.cursor() # The database will be saved in the location where your 'py' file is saved

# Create table - HOUSINGDATA
c.execute('''CREATE TABLE HOUSINGDATA
             ([generated_id] INTEGER PRIMARY KEY,
             [timestamp] date, 
             [URL] text, 
             [beschreibung] text, 
             [ga_cd_developer_virtualreality] text,
             [ga_cd_application_requirements] text, 
             [ga_cd_customer_group] text, 
             [ga_cd_cxp_historicallisting] text, 
             [ga_cd_maillead_default_shown] text, 
             [ga_cd_via] text, 
             [ga_cd_via_qualified] text, 
             [geo_bln] text, 
             [geo_krs] text, 
             [geo_land] text, 
             [geo_plz] integer, 
             [obj_ExclusiveExpose] text, 
             [obj_barrierFree] text, 
             [obj_buildingType] text, 
             [obj_cId] integer, 
             [obj_cellar] text, 
             [obj_condition] text, 
             [obj_constructionPhase] text, 
             [obj_courtage] text, 
             [obj_cwId] text, 
             [obj_energyEfficiencyClass] text, 
             [obj_energyType] text, 
             [obj_firingTypes] text, 
             [obj_galleryAd] text, 
             [obj_groupnumber] integer, 
             [obj_heatingType] text, 
             [obj_houseNumber] text, 
             [obj_immotype] text, 
             [obj_interiorQual] text, 
             [obj_international] text, 
             [obj_ityp] text, 
             [obj_lastRefurbish] integer, 
             [obj_livingSpace] integer, 
             [obj_livingSpaceRange] integer, 
             [obj_lotArea] integer, 
             [obj_newlyConst] text, 
             [obj_noParkSpaces] integer, 
             [obj_noRooms] integer, 
             [obj_noRoomsRange] integer, 
             [obj_numberOfFloors] integer, 
             [obj_objectnumber] text, 
             [obj_picture] text, 
             [obj_picturecount] integer, 
             [obj_plotAreaRange] integer, 
             [obj_pricetrend] integer, 
             [obj_pricetrendbuy] integer, 
             [obj_pricetrendrent] integer, 
             [obj_purchasePrice] integer, 
             [obj_purchasePriceRange] integer, 
             [obj_project_id] text,
             [obj_regio1] text, 
             [obj_regio2] text, 
             [obj_regio3] text, 
             [obj_rented] text, 
             [obj_scoutId] integer, 
             [obj_street] text, 
             [obj_streetPlain] text, 
             [obj_telekomDownloadSpeed] text, 
             [obj_telekomHdTelephone] text, 
             [obj_telekomHybridDownloadSpeed] text, 
             [obj_telekomHybridUploadSpeed] text, 
             [obj_telekomInternet] text, 
             [obj_telekomInternetProductAvailable] text, 
             [obj_telekomInternetProductName] text, 
             [obj_telekomInternetServices] text, 
             [obj_telekomInternetTechnology] text, 
             [obj_telekomInternetType] text, 
             [obj_telekomInternetUrl] text, 
             [obj_telekomInternetUrlMobile] text, 
             [obj_telekomTrackingGroup] text, 
             [obj_telekomTvOffer] text, 
             [obj_telekomUploadSpeed] text, 
             [obj_thermalChar] integer, 
             [obj_usableArea] integer, 
             [obj_yearConstructed] integer, 
             [obj_yearConstructedRange] integer, 
             [obj_zipCode] integer )''')
                 
conn.commit()
